# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tesla = pd.read_csv('bloglist.csv', header=None, sep=',')
tesla.columns = ['title', 'category', 'writer', 'date', 'contents', 'URL']
tesla
# Out:
#                                                title  category     writer  \
# 0                                  강남디테일링세차 나노디테일 추천        일상        푸드팔
# 1                         테슬라 400달러 리포트, 진짜 가능한 일일까?  어쩌다 어른경제   전인구경제연구소
# 2              글로벌 자율주행 대표 기업 Top 10 (5) - 테슬라 Tesla    IT 트렌드       노아시스
# 3                               넥스틸 PER 2배 영업이익률 27%      주식투자    창업의 지름신
# 4           [퓨런티어] 자율주행 시행착오는 퓨런티어의 성장동력 (f. 이베스트증권)      관심기업    Tracker
# ..                                               ...       ...        ...
# 295                              테슬라 썬팅 반사 필름은 어떠세요?   tinting       블락포디
# 296  증시 이슈 24년 미래 성장산업 신재생 자율주행 로봇 반도체 방산 우주항공 위성관련주      경제공부         미소
# 297                 테슬라 모델Y, 모던한 티나인 R70 과천 썬팅 시공 후기   프리미엄 썬팅  카스페이스 과천점
# 298                         [2023년09월21일] 투자핵심뉴스 (5)   투자관련 뉴스        민사랑
# 299      [주식 재테크] 영림원소프트랩 전망! 증시는 하락했지만 이종목만큼은 상승한다!   주식 공부자료     차트분석쟁이
#
#                    date                                           contents  \
# ...
